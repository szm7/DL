# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/dl5.csv")

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
data.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
data = data.drop(columns=['State'])

# %%
from sklearn.preprocessing import LabelEncoder

columns=['Voice mail plan','International plan','Churn']

for i in columns:
  encoder = LabelEncoder()
  data[i] = encoder.fit_transform(data[i])

# %%
data.head()
# Out:
#    Account length  Area code  International plan  Voice mail plan  \
# 0             117        408                   0                0
# 1              65        415                   0                0
# 2             161        415                   0                0
# 3             111        415                   0                0
# 4              49        510                   0                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
from sklearn.preprocessing import StandardScaler

dataScale = data.drop(columns=['Churn'])
for i in dataScale.columns:
    scale = StandardScaler()
    data[i] = scale.fit_transform(data[i].values.reshape(-1, 1))

# %%
data.head()
# Out:
#    Account length  Area code  International plan  Voice mail plan  \
# 0        0.347127  -0.674397           -0.293801        -0.628806
# 1       -0.927731  -0.506741           -0.293801        -0.628806
# 2        1.425853  -0.506741           -0.293801        -0.628806
# 3        0.200028  -0.506741           -0.293801        -0.628806
# 4       -1.319994   1.768601           -0.293801        -0.628806
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0              -0.601245           0.064036        -0.193167
# 1              -0.601245          -0.934756         1.769398
# 2              -0.601245           2.739500        -1.665090
# 3              -0.601245          -1.271894         0.101218
# 4              -0.601245          -1.111438         0.788115
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0          0.064504           2.983872        -1.081478          2.984789
# ...

# %%
x = data.drop(columns=['Churn'])
y = data['Churn']

# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
import matplotlib.pyplot as plt

epochs = 10


X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)

# Baseline DNN model without dropout
model_baseline = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Model with Dropout
model_with_dropout = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# Model with Layer-wise Dropout
model_layerwise_dropout = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# Model with Monte Carlo Dropout
model_monte_carlo_dropout = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

# Compile models
models = [model_baseline, model_with_dropout, model_layerwise_dropout, model_monte_carlo_dropout]

for model in models:
    model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# Train models
history = []
for model in models:
    hist = model.fit(X_train, y_train, epochs=epochs, validation_data=(X_val, y_val), verbose=0)
    history.append(hist.history)

# Evaluate models
metrics_dict = {}
for i, model in enumerate(models):
    y_pred = model.predict(X_val)
    y_pred_binary = (y_pred > 0.5).astype(int)

    accuracy = accuracy_score(y_val, y_pred_binary)
    f1 = f1_score(y_val, y_pred_binary)
    roc_auc = roc_auc_score(y_val, y_pred)

    metrics_dict[f"Model {i+1}"] = {'Accuracy': accuracy, 'F1 Score': f1, 'ROC AUC': roc_auc}

# Comparison and Visualization
for i, model in enumerate(models):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(history[i]['accuracy'], label='Training Accuracy')
    plt.plot(history[i]['val_accuracy'], label='Validation Accuracy')
    plt.title(f'Model {i+1} - Accuracy Curves')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history[i]['loss'], label='Training Loss')
    plt.plot(history[i]['val_loss'], label='Validation Loss')
    plt.title(f'Model {i+1} - Loss Curves')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Print performance metrics
for model, metrics in metrics_dict.items():
    print(f"\n{model} Metrics:")
    for metric, value in metrics.items():
        print(f"{metric}: {value}")
# Out:
# ...
# 5/5 [==============================] - 0s 2ms/step
# Model 1 Metrics:
# Accuracy: 0.9328358208955224
# F1 Score: 0.64
# ROC AUC: 0.8364145658263306
#
# Model 2 Metrics:
# Accuracy: 0.8880597014925373
# F1 Score: 0.0
# ROC AUC: 0.6873949579831933
#
# Model 3 Metrics:
# Accuracy: 0.9029850746268657
# F1 Score: 0.31578947368421056
# ROC AUC: 0.7630252100840337
#
# Model 4 Metrics:
# Accuracy: 0.9328358208955224
# F1 Score: 0.5714285714285715
# ROC AUC: 0.7904761904761904
